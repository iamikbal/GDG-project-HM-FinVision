# %%
import yfinance as yf
from statsmodels.tsa.stattools import adfuller, kpss
import matplotlib.pyplot as plt
import pandas as pd

# %%
def adf_test(series):
    result = adfuller(series, autolag='AIC')
    return {
        'Test Statistic': result[0],
        'p-value': result[1],
        'Lags Used': result[2],
        'Number of Observations': result[3],
        'Critical Values': result[4],
        'Stationary': result[1] < 0.05  # True if p-value < 0.05
    }

# %%
def kpss_test(series):
    result = kpss(series, regression='c', nlags="auto")
    return {
        'Test Statistic': result[0],
        'p-value': result[1],
        'Lags Used': result[2],
        'Critical Values': result[3],
        'Stationary': result[1] > 0.05  # True if p-value > 0.05
    }

# %%
def fetch_stock_data(ticker):
    data = yf.download(ticker, start="2023-01-01", end="2024-11-30")
    return data['Close']

# %%
companies = [
    "BHARTIARTL",
    "ITC",
    "KOTAKBANK",
    "HINDUNILVR",
    "ULTRACEMCO",
    "TITAN",
    "POWERGRID",
    "HCLTECH",
    "NESTLEIND",
    "GRASIM",
    "ADANIPORTS",
    "ICICIBANK",
    "HDFCLIFE",
    "SBIN",
    "MARUTI",
    "RELIANCE",
    "ADANIENT",
    "BEL",
    "ASIANPAINT",
    "TATACONSUM",
    "LT",
    "HDFCBANK",
    "BAJFINANCE",
    "BAJAJ-AUTO",
    "NTPC",
    "INFY",
    "TATAMOTORS",
    "AXISBANK",
    "TECHM",
    "M&M",
    "COALINDIA",
    "EICHERMOT",
    "TCS",
    "APOLLOHOSP",
    "HEROMOTOCO",
    "ONGC",
    "WIPRO",
    "SUNPHARMA",
    "BRITANNIA",
    "CIPLA",
    "DRREDDY",
    "BAJAJFINSV",
    "BPCL",
    "SBILIFE",
    "TRENT",
    "HINDALCO",
    "JSWSTEEL",
    "INDUSINDBK",
    "TATASTEEL",
    "SHRIRAMFIN"
]

# %%
res = []
for company in companies:
    data = fetch_stock_data(f'{company}.NS')
    adf_result = adf_test(data)
    kpss_result = kpss_test(data)
    res.append({
        'Company': company,
        'ADF': adf_result['Stationary'],
        'KPSS': kpss_result['Stationary']
    })
# Out:
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-6-4aea805c72ab>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series, regression='c', nlags="auto")

# %%
df = pd.DataFrame(res)

# %%
df
# Out:
#        Company    ADF   KPSS
# 0   BHARTIARTL  False  False
# 1          ITC  False  False
# 2    KOTAKBANK   True   True
# 3   HINDUNILVR  False   True
# 4   ULTRACEMCO  False  False
# 5        TITAN  False  False
# 6    POWERGRID  False  False
# 7      HCLTECH  False  False
# 8    NESTLEIND  False  False
# 9       GRASIM  False  False
# 10  ADANIPORTS  False  False
# 11   ICICIBANK  False  False
# 12    HDFCLIFE  False  False
# 13        SBIN  False  False
# 14      MARUTI  False  False
# 15    RELIANCE  False  False
# 16    ADANIENT  False  False
# 17         BEL  False  False
# 18  ASIANPAINT  False   True
# 19  TATACONSUM  False  False
# 20          LT  False  False
# 21    HDFCBANK  False  False
# 22  BAJFINANCE  False  False
# 23  BAJAJ-AUTO  False  False
# 24        NTPC  False  False
# 25        INFY  False  False
# 26  TATAMOTORS  False  False
# 27    AXISBANK  False  False
# 28       TECHM  False  False
# 29         M&M  False  False
# 30   COALINDIA  False  False
# 31   EICHERMOT  False  False
# 32         TCS  False  False
# 33  APOLLOHOSP  False  False
# 34  HEROMOTOCO  False  False
# 35        ONGC  False  False
# 36       WIPRO  False  False
# 37   SUNPHARMA  False  False
# 38   BRITANNIA  False  False
# 39       CIPLA  False  False
# 40     DRREDDY  False  False
# 41  BAJAJFINSV  False  False
# 42        BPCL  False  False
# 43     SBILIFE  False  False
# 44       TRENT  False  False
# 45    HINDALCO  False  False
# 46    JSWSTEEL  False  False
# 47  INDUSINDBK  False  False
# 48   TATASTEEL  False  False
# 49  SHRIRAMFIN  False  False
